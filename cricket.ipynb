# %%
 #Test batting or bowling
    #page='https://stats.espncricinfo.com/ci/engine/stats/index.html?class=1;filter=advanced;orderby=start;page={};template=results;type=fow;view=innings'
    
    #Test Partnership
    #page='https://stats.espncricinfo.com/ci/engine/stats/index.html?class=1;filter=advanced;orderby=start;page={};template=results;type=fow;view=innings'
    
    #Test Fielding
    #page = 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=1;filter=advanced;orderby=start;page={};qualmin1=1;qualval1=fielded_dismissals;template=results;type=fielding;view=innings'
    
    #ODI batting
    #page = 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;filter=advanced;orderby=start;page={};template=results;type=batting;view=innings'
 


         #Batting & Bowling
        #txt = tr_class[i].select('td')[0].getText()+'      '+tr_class[i].select('a')[1].getText()+'      '+tr_class[i].select('td')[1].getText()+'      '+tr_class[i].select('td')[2].getText()+'      '+tr_class[i].select('td')[3].getText()+'      '+tr_class[i].select('td')[4].getText()+'      '+tr_class[i].select('td')[5].getText()+'      '+tr_class[i].select('td')[6].getText()+'      '+tr_class[i].select('td')[7].getText()+'      '+tr_class[i].select('a')[2].getText()+'      '+tr_class[i].select('b')[0].getText()
        
        #Partnership
        #txt = tr_class[i].select('td')[0].getText()+'      '+tr_class[i].select('td')[1].getText()+'      '+tr_class[i].select('td')[2].getText()+'      '+tr_class[i].select('td')[3].getText()+'      '+tr_class[i].select('td')[4].getText()+'      '+tr_class[i].select('td')[5].getText()+'      '+tr_class[i].select('td')[7].getText()+'      '+tr_class[i].select('td')[8].getText()+'      '+tr_class[i].select('td')[9].getText()
        
        #Fielding
        #txt = tr_class[i].select('td')[0].getText()+'      '+tr_class[i].select('td')[1].getText()+'      '+tr_class[i].select('td')[2].getText()+'      '+tr_class[i].select('td')[3].getText()+'      '+tr_class[i].select('td')[4].getText()+'      '+tr_class[i].select('td')[5].getText()+'      '+tr_class[i].select('td')[6].getText()+'      '+tr_class[i].select('td')[7].getText()+'      '+tr_class[i].select('td')[8].getText()+'      '+tr_class[i].select('td')[9].getText()+'      '+tr_class[i].select('td')[10].getText()

# %%
import bs4
import requests
import datetime
import csv
print(datetime.datetime.now())
for i in range(1,2):
      
    page = 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;filter=advanced;orderby=start;page={};template=results;type=bowling;view=innings'
    
    source = requests.get(page.format(i+1))
    soup = bs4.BeautifulSoup(source.text,'lxml')

    tr_class = soup.select('.data1')

    f = open('to_save_file.csv',mode='a', newline = '')
    csv_writer = csv.writer(f, delimiter = ',')
    
    total = len(tr_class)

    for i in range(total):
       
        #ODI Batting
        txt = tr_class[i].select('td')[0].getText()+'      '+tr_class[i].select('td')[1].getText()+'      '+tr_class[i].select('td')[3].getText()+'      '+tr_class[i].select('td')[4].getText()+'      '+tr_class[i].select('td')[5].getText()+'      '+tr_class[i].select('td')[6].getText()+'      '+tr_class[i].select('td')[7].getText()+'      '+tr_class[i].select('td')[8].getText()+'      '+tr_class[i].select('td')[9].getText()+'      '+tr_class[i].select('td')[10].getText()+'      '+tr_class[i].select('td')[11].getText()
        
        #txt = tr_class[i].select('td')[0].getText()+'      '+tr_class[i].select('td')[1].getText()+'      '+tr_class[i].select('td')[2].getText()+'      '+tr_class[i].select('td')[3].getText()+'      '+tr_class[i].select('td')[4].getText()+'      '+tr_class[i].select('td')[5].getText()+'      '+tr_class[i].select('td')[7].getText()+'      '+tr_class[i].select('td')[8].getText()+'      '+tr_class[i].select('td')[9].getText()
       
        
        csv_writer.writerow([tr_class[i].select('td')[0].getText(),tr_class[i].select('td')[1].getText(),tr_class[i].select('td')[3].getText(),tr_class[i].select('td')[4].getText(),tr_class[i].select('td')[5].getText(),tr_class[i].select('td')[6].getText(),tr_class[i].select('td')[7].getText(),tr_class[i].select('td')[8].getText(),tr_class[i].select('td')[9].getText(),tr_class[i].select('td')[10].getText(),tr_class[i].select('td')[11].getText()])
        
        
        #f.write(txt)
        #f.write('\n')
f.close()
print(datetime.datetime.now())
# Out:
# 2023-01-11 18:19:00.210850
# 2023-01-11 18:19:04.032058

# %%
import bs4
import requests
import datetime

urls = ['https://www.espncricinfo.com/series/indian-premier-league-2009-10-418064/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/indian-premier-league-2011-466304/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/indian-premier-league-2012-520932/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/indian-premier-league-2013-586733/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/pepsi-indian-premier-league-2014-695871/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/pepsi-indian-premier-league-2015-791129/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/ipl-2016-968923/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/ipl-2017-1078425/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/ipl-2018-1131611/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/ipl-2019-1165643/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/ipl-2020-21-1210595/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/ipl-2021-1249214/match-schedule-fixtures-and-results',
       'https://www.espncricinfo.com/series/indian-premier-league-2022-1298423/match-schedule-fixtures-and-results']
year = 2010
for url in urls:
    print('********************************************'+str(year)+'************************************************************')
    result = requests.get(url)
    soup = bs4.BeautifulSoup(result.text,'lxml')
    length = len(soup.select('.ds-no-tap-higlight'))
    for i in range(length):
        text = soup.select('.ds-no-tap-higlight')[i].getText()
        if "Indian Premier League" in text:
            print(text)
    year = year+1
# Out:
# ********************************************2010************************************************************
# RESULT1st match (N), DY Patil, March 12, 2010, Indian Premier LeagueKolkata Knight Riders161/4Deccan Chargers(20 ov, T:162) 150/7KKR won by 11 runs
# RESULT2nd match (D/N), Brabourne, March 13, 2010, Indian Premier LeagueMumbai Indians212/6Rajasthan Royals(20 ov, T:213) 208/7Mumbai won by 4 runs
# RESULT3rd match (N), Mohali, March 13, 2010, Indian Premier LeagueKings XI Punjab142/9Delhi Daredevils(19.5/20 ov, T:143) 146/5Daredevils won by 5 wickets (with 1 ball remaining)
# RESULT4th match (D/N), Eden Gardens, March 14, 2010, Indian Premier LeagueRoyal Challengers Bangalore135/7Kolkata Knight Riders(19.2/20 ov, T:136) 136/3KKR won by 7 wickets (with 4 balls remaining)
# RESULT5th match (N), Chennai, March 14, 2010, Indian Premier LeagueDeccan Chargers190/4Chennai Super Kings(20 ov, T:191) 159/9Chargers won by 31 runs
# ...

# %% [markdown]
# ##### soup.select('div')[234].select('a')

# %%
soup.select('.ds-no-tap-higlight')
# Out:
# [<a class="ds-no-tap-higlight" href="/series/england-in-pakistan-2022-23-1330866/pakistan-vs-england-3rd-test-1330873/live-cricket-score"><div class="ds-text-compact-xxs"><div class="ds-relative ds-w-[288px] card scorecard"><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate ds-text-raw-red"><span class="ds-text-tight-xs ds-font-bold ds-uppercase ds-leading-5">Stumps</span><span class="ds-text-tight-xs ds-text-typo-paragraph"><span class="ds-text-tight-xs ds-font-medium"> • <!-- -->3rd TEST</span> • <!-- --> <!-- -->Karachi</span></div><div class="ds-leading-[0]"></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo-title ds-mb-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="PAK"><img alt="PAK Flag" class="ds-mr-2" height="20" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width:20px;height:20px" width="
# ...

# %%
len(soup.select('a'))
# Out:
# 277
